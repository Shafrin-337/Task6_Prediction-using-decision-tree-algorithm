# %% [markdown]
# # Task-6: Prediction using Decision Tree Algorithm

# %% [markdown]
# ## Presented By: Shafrin Sultana

# %% [markdown]
# ### Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn import tree

# %% [markdown]
# ### Importing Data

# %%
myData=pd.read_csv('data_6.txt',delimiter=',')

# %% [markdown]
# ### Show Data Table

# %%
myData.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Visualize data

# %%
sns.pairplot(myData.drop(['Id'],axis=1),hue='Species')
plt.show()

# %% [markdown]
# ### Data Slicing

# %%
Input=myData.loc[:,['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
target=myData.loc[:,'Species']

# %% [markdown]
# ### Tree Model for the given Data

# %%
newModel=DecisionTreeClassifier().fit(Input,target)
plt.figure(figsize=(20,15))
tree=tree.plot_tree(newModel,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],class_names=['Iris-setosa','Iris-Versicolor','Iris-Virginica'],filled=True)

# %% [markdown]
# ### Data splitting for training and testing purpose

# %%
X_train, X_test, y_train, y_test = train_test_split( 
          Input, target, test_size = 0.3, random_state = 100)

# %%
print(X_train.shape
,X_test.shape
,y_train.shape
,y_test.shape)
# Out:
# (105, 4) (45, 4) (105,) (45,)

# %% [markdown]
# ### Tree model Initialization in purpose of testing sepcies based on the given data

# %%
treeModel=DecisionTreeClassifier()
treeModel.fit(X_train,y_train)
predictedOutput=treeModel.predict(X_test)

# %% [markdown]
# ### Compare the Actual and Predicted Species

# %%
comparisonTable=pd.DataFrame({'Actual Species':y_test,'Predicted Species':predictedOutput})

# %%
comparisonTable
# Out:
#       Actual Species Predicted Species
# 128   Iris-virginica    Iris-virginica
# 11       Iris-setosa       Iris-setosa
# 118   Iris-virginica    Iris-virginica
# 15       Iris-setosa       Iris-setosa
# 123   Iris-virginica    Iris-virginica
# 135   Iris-virginica    Iris-virginica
# 32       Iris-setosa       Iris-setosa
# 1        Iris-setosa       Iris-setosa
# 116   Iris-virginica    Iris-virginica
# 45       Iris-setosa       Iris-setosa
# 40       Iris-setosa       Iris-setosa
# 115   Iris-virginica    Iris-virginica
# 26       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa
# 145   Iris-virginica    Iris-virginica
# 97   Iris-versicolor   Iris-versicolor
# 62   Iris-versicolor   Iris-versicolor
# 77   Iris-versicolor    Iris-virginica
# 122   Iris-virginica    Iris-virginica
# 112   Iris-virginica    Iris-virginica
# 125   Iris-virginica    Iris-virginica
# 31       Iris-setosa       Iris-setosa
# 146   Iris-virginica    Iris-virginica
# ...

# %% [markdown]
# ### Tree model for the testing data where the species data are collected from the given dataset

# %%
from sklearn import tree
testModel=DecisionTreeClassifier().fit(X_test,y_test)
plt.figure(figsize=(7,7))
tree1=tree.plot_tree(testModel,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],class_names=['Iris-setosa','Iris-Versicolor','Iris-Virginica'],filled=True)

# %% [markdown]
# ### Tree model for the testing data where the species data are predicted

# %%
from sklearn import tree
testModel=DecisionTreeClassifier().fit(X_test,predictedOutput)
plt.figure(figsize=(7,7))
tree2=tree.plot_tree(testModel,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],class_names=['Iris-setosa','Iris-Versicolor','Iris-Virginica'],filled=True)

# %% [markdown]
# ### Accuracy Calculation

# %%
accuracy_score(y_test,predictedOutput)
# Out:
# 0.9555555555555556
